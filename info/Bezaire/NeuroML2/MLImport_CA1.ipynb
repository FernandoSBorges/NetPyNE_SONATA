# %%
from netpyne import sim
from netpyne import specs


nml2_file_name = 'SimpleNet.net.nml'

simConfig = specs.SimConfig()  # dictionary to store simConfig

# Simulation parameters
simConfig.duration = 10000 # Duration of the simulation, in ms
simConfig.dt = 0.025 # Internal integration timestep to use
simConfig.verbose = True

simConfig.recordCells = ['all']  # which cells to record from
simConfig.recordTraces = {'Vsoma':{'sec':'soma','loc':0.5,'var':'v'}}
simConfig.filename = 'axoaxonicnet'  # Set file output name
simConfig.saveDat = True # save traces


simConfig.plotRaster = True # Whether or not to plot a raster
simConfig.plotCells = ['all'] # plot recorded traces for this list of cells

sim.importNeuroML2SimulateAnalyze(nml2_file_name,simConfig)
# Out:
# Importing NeuroML 2 network from: SimpleNet.net.nml
# Parsing: SimpleNet.net.nml
# Loaded: SimpleNet.net.nml as NeuroMLDocument
# Setting global temperature to 32.0
# Finished import of NeuroML2; populations vs gids NML has calculated:
#    RS_pop: [0, 1, 2]
#    axoaxoniccell: [0, 1, 2]
#
# Start time:  2021-03-10 20:03:23.762834
#
# Creating network of 2 cell populations on 1 hosts...
# Distributed population of 3 cells on 1 hosts: {0: [0, 1, 2]}, next: 0
# Cell 0/2 (gid=0) of pop 0, on node 0,
# Cell 1/2 (gid=1) of pop 1, on node 0,
# Cell 2/2 (gid=2) of pop 2, on node 0,
# Instantiated 3 cells of population RS_pop
# Distributed population of 3 cells on 1 hosts: {0: [0, 1, 2]}, next: 0
# # Error inserting KCaS mechanims in soma_0 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in soma_0 section! (check mod files are compiled)
# # Error inserting KvA mechanims in soma_0 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in soma_0 section! (check mod files are compiled)
# # Error inserting Nav mechanims in soma_0 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in soma_0 section! (check mod files are compiled)
# # Error inserting CavN mechanims in soma_0 section! (check mod files are compiled)
# # Error inserting ca ion in soma_0 section!
# # Error inserting KCaS mechanims in dend_13 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_13 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_13 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_13 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_13 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_13 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_13 section! (check mod files are compiled)
# # Error inserting ca ion in dend_13 section!
# # Error inserting KCaS mechanims in dend_10 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_10 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_10 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_10 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_10 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_10 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_10 section! (check mod files are compiled)
# # Error inserting ca ion in dend_10 section!
# # Error inserting KCaS mechanims in dend_5 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_5 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_5 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_5 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_5 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_5 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_5 section! (check mod files are compiled)
# # Error inserting ca ion in dend_5 section!
# # Error inserting KCaS mechanims in dend_0 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_0 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_0 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_0 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_0 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_0 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_0 section! (check mod files are compiled)
# # Error inserting ca ion in dend_0 section!
# # Error inserting KCaS mechanims in dend_14 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_14 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_14 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_14 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_14 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_14 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_14 section! (check mod files are compiled)
# # Error inserting ca ion in dend_14 section!
# # Error inserting KCaS mechanims in dend_11 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_11 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_11 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_11 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_11 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_11 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_11 section! (check mod files are compiled)
# # Error inserting ca ion in dend_11 section!
# # Error inserting KCaS mechanims in dend_6 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_6 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_6 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_6 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_6 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_6 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_6 section! (check mod files are compiled)
# # Error inserting ca ion in dend_6 section!
# # Error inserting KCaS mechanims in dend_1 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_1 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_1 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_1 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_1 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_1 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_1 section! (check mod files are compiled)
# # Error inserting ca ion in dend_1 section!
# # Error inserting KCaS mechanims in dend_15 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_15 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_15 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_15 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_15 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_15 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_15 section! (check mod files are compiled)
# # Error inserting ca ion in dend_15 section!
# # Error inserting KCaS mechanims in dend_12 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_12 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_12 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_12 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_12 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_12 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_12 section! (check mod files are compiled)
# # Error inserting ca ion in dend_12 section!
# # Error inserting KCaS mechanims in dend_7 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_7 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_7 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_7 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_7 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_7 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_7 section! (check mod files are compiled)
# # Error inserting ca ion in dend_7 section!
# # Error inserting KCaS mechanims in dend_2 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_2 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_2 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_2 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_2 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_2 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_2 section! (check mod files are compiled)
# # Error inserting ca ion in dend_2 section!
# # Error inserting KCaS mechanims in dend_8 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_8 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_8 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_8 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_8 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_8 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_8 section! (check mod files are compiled)
# # Error inserting ca ion in dend_8 section!
# # Error inserting KCaS mechanims in dend_3 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_3 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_3 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_3 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_3 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_3 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_3 section! (check mod files are compiled)
# # Error inserting ca ion in dend_3 section!
# # Error inserting KCaS mechanims in dend_9 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_9 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_9 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_9 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_9 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_9 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_9 section! (check mod files are compiled)
# # Error inserting ca ion in dend_9 section!
# # Error inserting KCaS mechanims in dend_4 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_4 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_4 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_4 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_4 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_4 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_4 section! (check mod files are compiled)
# # Error inserting ca ion in dend_4 section!
# ERROR: Some mechanisms and/or ions were not inserted (for details run with cfg.verbose=True). Make sure the required mod files are compiled.
# Cell 0/2 (gid=3) of pop 0, on node 0,
# # Error inserting KCaS mechanims in soma_0 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in soma_0 section! (check mod files are compiled)
# # Error inserting KvA mechanims in soma_0 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in soma_0 section! (check mod files are compiled)
# # Error inserting Nav mechanims in soma_0 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in soma_0 section! (check mod files are compiled)
# # Error inserting CavN mechanims in soma_0 section! (check mod files are compiled)
# # Error inserting ca ion in soma_0 section!
# # Error inserting KCaS mechanims in dend_13 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_13 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_13 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_13 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_13 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_13 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_13 section! (check mod files are compiled)
# # Error inserting ca ion in dend_13 section!
# # Error inserting KCaS mechanims in dend_10 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_10 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_10 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_10 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_10 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_10 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_10 section! (check mod files are compiled)
# # Error inserting ca ion in dend_10 section!
# # Error inserting KCaS mechanims in dend_5 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_5 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_5 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_5 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_5 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_5 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_5 section! (check mod files are compiled)
# # Error inserting ca ion in dend_5 section!
# # Error inserting KCaS mechanims in dend_0 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_0 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_0 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_0 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_0 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_0 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_0 section! (check mod files are compiled)
# # Error inserting ca ion in dend_0 section!
# # Error inserting KCaS mechanims in dend_14 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_14 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_14 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_14 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_14 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_14 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_14 section! (check mod files are compiled)
# # Error inserting ca ion in dend_14 section!
# # Error inserting KCaS mechanims in dend_11 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_11 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_11 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_11 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_11 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_11 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_11 section! (check mod files are compiled)
# # Error inserting ca ion in dend_11 section!
# # Error inserting KCaS mechanims in dend_6 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_6 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_6 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_6 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_6 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_6 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_6 section! (check mod files are compiled)
# # Error inserting ca ion in dend_6 section!
# # Error inserting KCaS mechanims in dend_1 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_1 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_1 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_1 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_1 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_1 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_1 section! (check mod files are compiled)
# # Error inserting ca ion in dend_1 section!
# # Error inserting KCaS mechanims in dend_15 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_15 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_15 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_15 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_15 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_15 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_15 section! (check mod files are compiled)
# # Error inserting ca ion in dend_15 section!
# # Error inserting KCaS mechanims in dend_12 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_12 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_12 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_12 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_12 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_12 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_12 section! (check mod files are compiled)
# # Error inserting ca ion in dend_12 section!
# # Error inserting KCaS mechanims in dend_7 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_7 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_7 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_7 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_7 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_7 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_7 section! (check mod files are compiled)
# # Error inserting ca ion in dend_7 section!
# # Error inserting KCaS mechanims in dend_2 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_2 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_2 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_2 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_2 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_2 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_2 section! (check mod files are compiled)
# # Error inserting ca ion in dend_2 section!
# # Error inserting KCaS mechanims in dend_8 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_8 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_8 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_8 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_8 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_8 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_8 section! (check mod files are compiled)
# # Error inserting ca ion in dend_8 section!
# # Error inserting KCaS mechanims in dend_3 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_3 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_3 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_3 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_3 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_3 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_3 section! (check mod files are compiled)
# # Error inserting ca ion in dend_3 section!
# # Error inserting KCaS mechanims in dend_9 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_9 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_9 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_9 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_9 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_9 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_9 section! (check mod files are compiled)
# # Error inserting ca ion in dend_9 section!
# # Error inserting KCaS mechanims in dend_4 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_4 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_4 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_4 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_4 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_4 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_4 section! (check mod files are compiled)
# # Error inserting ca ion in dend_4 section!
# ERROR: Some mechanisms and/or ions were not inserted (for details run with cfg.verbose=True). Make sure the required mod files are compiled.
# Cell 1/2 (gid=4) of pop 1, on node 0,
# # Error inserting KCaS mechanims in soma_0 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in soma_0 section! (check mod files are compiled)
# # Error inserting KvA mechanims in soma_0 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in soma_0 section! (check mod files are compiled)
# # Error inserting Nav mechanims in soma_0 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in soma_0 section! (check mod files are compiled)
# # Error inserting CavN mechanims in soma_0 section! (check mod files are compiled)
# # Error inserting ca ion in soma_0 section!
# # Error inserting KCaS mechanims in dend_13 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_13 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_13 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_13 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_13 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_13 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_13 section! (check mod files are compiled)
# # Error inserting ca ion in dend_13 section!
# # Error inserting KCaS mechanims in dend_10 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_10 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_10 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_10 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_10 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_10 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_10 section! (check mod files are compiled)
# # Error inserting ca ion in dend_10 section!
# # Error inserting KCaS mechanims in dend_5 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_5 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_5 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_5 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_5 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_5 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_5 section! (check mod files are compiled)
# # Error inserting ca ion in dend_5 section!
# # Error inserting KCaS mechanims in dend_0 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_0 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_0 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_0 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_0 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_0 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_0 section! (check mod files are compiled)
# # Error inserting ca ion in dend_0 section!
# # Error inserting KCaS mechanims in dend_14 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_14 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_14 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_14 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_14 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_14 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_14 section! (check mod files are compiled)
# # Error inserting ca ion in dend_14 section!
# # Error inserting KCaS mechanims in dend_11 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_11 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_11 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_11 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_11 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_11 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_11 section! (check mod files are compiled)
# # Error inserting ca ion in dend_11 section!
# # Error inserting KCaS mechanims in dend_6 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_6 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_6 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_6 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_6 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_6 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_6 section! (check mod files are compiled)
# # Error inserting ca ion in dend_6 section!
# # Error inserting KCaS mechanims in dend_1 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_1 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_1 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_1 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_1 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_1 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_1 section! (check mod files are compiled)
# # Error inserting ca ion in dend_1 section!
# # Error inserting KCaS mechanims in dend_15 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_15 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_15 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_15 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_15 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_15 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_15 section! (check mod files are compiled)
# # Error inserting ca ion in dend_15 section!
# # Error inserting KCaS mechanims in dend_12 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_12 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_12 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_12 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_12 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_12 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_12 section! (check mod files are compiled)
# # Error inserting ca ion in dend_12 section!
# # Error inserting KCaS mechanims in dend_7 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_7 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_7 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_7 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_7 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_7 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_7 section! (check mod files are compiled)
# # Error inserting ca ion in dend_7 section!
# # Error inserting KCaS mechanims in dend_2 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_2 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_2 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_2 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_2 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_2 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_2 section! (check mod files are compiled)
# # Error inserting ca ion in dend_2 section!
# # Error inserting KCaS mechanims in dend_8 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_8 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_8 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_8 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_8 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_8 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_8 section! (check mod files are compiled)
# # Error inserting ca ion in dend_8 section!
# # Error inserting KCaS mechanims in dend_3 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_3 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_3 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_3 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_3 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_3 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_3 section! (check mod files are compiled)
# # Error inserting ca ion in dend_3 section!
# # Error inserting KCaS mechanims in dend_9 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_9 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_9 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_9 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_9 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_9 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_9 section! (check mod files are compiled)
# # Error inserting ca ion in dend_9 section!
# # Error inserting KCaS mechanims in dend_4 section! (check mod files are compiled)
# # Error inserting Kdrfast mechanims in dend_4 section! (check mod files are compiled)
# # Error inserting KvA mechanims in dend_4 section! (check mod files are compiled)
# # Error inserting KvCaB mechanims in dend_4 section! (check mod files are compiled)
# # Error inserting Nav mechanims in dend_4 section! (check mod files are compiled)
# # Error inserting leak_chan mechanims in dend_4 section! (check mod files are compiled)
# # Error inserting CavN mechanims in dend_4 section! (check mod files are compiled)
# # Error inserting ca ion in dend_4 section!
# ERROR: Some mechanisms and/or ions were not inserted (for details run with cfg.verbose=True). Make sure the required mod files are compiled.
# Cell 2/2 (gid=5) of pop 2, on node 0,
# Instantiated 3 cells of population axoaxoniccell
#   Number of cells on node 0: 6
#   Done; cell creation time = 0.15 s.
# gid: RS_pop: <netpyne.network.pop.Pop object at 0x000001AD20D28760>, [0, 1, 2]
# gid: axoaxoniccell: <netpyne.network.pop.Pop object at 0x000001AD20D28790>, [3, 4, 5]
# C:\Users\Pietra\anaconda3\lib\site-packages\neuroml\hdf5\NeuroMLXMLParser.py:98: DeprecationWarning: inspect.getargspec() is deprecated since Python 3.0, use inspect.signature() or inspect.getfullargspec()
#   if 'properties' in inspect.getargspec(self.netHandler.handle_population)[0]:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-11-68c3d84daf38> in <module>
#      21 simConfig.plotCells = ['all'] # plot recorded traces for this list of cells
#      22
# ---> 23 sim.importNeuroML2SimulateAnalyze(nml2_file_name,simConfig)
#
# c:\users\pietra\netpyne\netpyne\sim\wrappers.py in importNeuroML2SimulateAnalyze(fileName, simConfig)
#     431     from .. import sim
#     432
# --> 433     return sim.importNeuroML2(fileName, simConfig, simulate=True, analyze=True)
#
# c:\users\pietra\netpyne\netpyne\conversion\neuromlFormat.py in importNeuroML2(fileName, simConfig, simulate, analyze)
#    1491             if sim.cfg.verbose: print("gid: %s: %s, %s"%(popLabel,pop, pop.cellGids))
#    1492             for gid in pop.cellGids:
# -> 1493                 assert gid in nmlHandler.gids[popLabel]
#    1494
#    1495         for proj_id in list(nmlHandler.projection_infos.keys()):
#
# AssertionError:

# %%
# %tb
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-68c3d84daf38> in <module>
#      21 simConfig.plotCells = ['all'] # plot recorded traces for this list of cells
#      22
# ---> 23 sim.importNeuroML2SimulateAnalyze(nml2_file_name,simConfig)
#
# c:\users\pietra\netpyne\netpyne\sim\wrappers.py in importNeuroML2SimulateAnalyze(fileName, simConfig)
#     431     from .. import sim
#     432
# --> 433     return sim.importNeuroML2(fileName, simConfig, simulate=True, analyze=True)
#
# c:\users\pietra\netpyne\netpyne\conversion\neuromlFormat.py in importNeuroML2(fileName, simConfig, simulate, analyze)
#    1450             currParser = NeuroMLXMLParser(nmlHandler) # The XML handler knows of the structure of NeuroML and calls appropriate functions in NetworkHandler
#    1451
# -> 1452             currParser.parse(fileName)
#    1453
#    1454             nmlHandler.finalise()
#
# ~\anaconda3\lib\site-packages\neuroml\hdf5\NeuroMLXMLParser.py in parse(self, filename)
#      97
#      98                 if 'properties' in inspect.getargspec(self.netHandler.handle_population)[0]:
# ---> 99                     self.netHandler.handle_population(population.id,
#     100                                                      population.component,
#     101                                                      len(population.instances),
#
# c:\users\pietra\netpyne\netpyne\conversion\neuromlFormat.py in handle_population(self, population_id, component, size, component_obj, properties)
#     831             self.pop_ids_vs_components[population_id] = component_obj
#     832
# --> 833             assert(component==component_obj.id)
#     834
#     835             popInfo=OrderedDict()
#
# AttributeError: 'NoneType' object has no attribute 'id'
