# %%
# !nrnivmodl mod

# %%
CircuitPath = '/home/fernando/CA1_netpyne/info/data-bbp/20191017/'

BioName = CircuitPath + 'bioname/'

Atlas = CircuitPath + 'atlas/'
MorphologyPath = CircuitPath + 'morphologies/swc/'
# nrnPath = CircuitPath + 'sonata/edges/edges_hippocampus.h5'
CellLibraryFile = CircuitPath + 'sonata/nodes/nodes_hippocampus.h5'

METypePath = CircuitPath + 'emodels/20190402/hoc/'
MEComboInfoFile = CircuitPath + 'emodels/20190402/mecombo_emodel.tsv'

TargetFile = CircuitPath + 'user.target'
StartFile = CircuitPath + 'start.target'

# Path = CircuitPath + 'sonata/edges/edges_hippocampus_projections.h5'

# %%
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn
import json

from bluepysnap import Circuit
from bluepysnap.bbp import Cell
circuit_path = CircuitPath + 'circuit_config.json'
circuit = Circuit(circuit_path)
cells = circuit.nodes["hippocampus_neurons"]
# conn = circuit.edges["hippocampus_neurons__hippocampus_neurons__chemical"]

# %%
# from bluepysnap import Simulation

# sim = Simulation(CircuitPath +'/simulations/activate_minis/minis/simulation_config.json')
# spikes = sim.spikes
# hippocampus_spikes = spikes["hippocampus_neurons"]

# %% [markdown]
# ## Cells info

# %%
nodesinfo = cells.get()
nodesinfo
# Out:
#       etype layer                            model_template   model_type  \
# 0       bAC   SLM   hoc:CA1_int_bAC_011127HP1_2019032911561  biophysical
# 1       bAC   SLM   hoc:CA1_int_bAC_011127HP1_2019032911561  biophysical
# 2       bAC   SLM   hoc:CA1_int_bAC_011127HP1_2019032911561  biophysical
# 3       cAC    SR   hoc:CA1_int_cAC_990611HP2_2019032816214  biophysical
# 4       cAC    SR   hoc:CA1_int_cAC_990611HP2_2019032816214  biophysical
# ...     ...   ...                                       ...          ...
# 18193  cNAC    SO    hoc:CA1_int_cNAC_970717D_2019030718251  biophysical
# 18194  cNAC    SO    hoc:CA1_int_cNAC_970911C_2019030512040  biophysical
# 18195  cNAC    SO    hoc:CA1_int_cNAC_970911C_2019030512040  biophysical
# 18196  cNAC    SO  hoc:CA1_int_cNAC_990111HP2_2019032915570  biophysical
# 18197  cNAC    SO  hoc:CA1_int_cNAC_970509HP2_2019030511562  biophysical
#
#       morph_class                                      morphology    mtype  \
# 0             INT          011127HP1_-_Scale_x1.000_y0.850_z1.000  SLM_PPA
# 1             INT          011127HP1_-_Scale_x1.000_y0.850_z1.000  SLM_PPA
# 2             INT          011127HP1_-_Scale_x1.000_y0.850_z1.000  SLM_PPA
# 3             INT                                       990611HP2   SR_SCA
# 4             INT          990611HP2_-_Scale_x1.000_y1.050_z1.000   SR_SCA
# ...           ...                                             ...      ...
# 18193         INT                                         980120A    SO_BP
# 18194         INT            980120A_-_Scale_x1.000_y1.150_z1.000    SO_BP
# 18195         INT  980120A_-_Scale_x1.000_y0.850_z1.000_-_Clone_0    SO_BP
# 18196         INT            980120A_-_Scale_x1.000_y1.150_z1.000    SO_BP
# 18197         INT            980120A_-_Scale_x1.000_y1.150_z1.000    SO_BP
#
#         region  rotation_angle_xaxis  rotation_angle_yaxis  \
# 0      mc5;SLM             -0.000000              0.306704
# 1      mc3;SLM             -3.141593              1.051681
# 2      mc6;SLM             -3.141593              1.393882
# 3       mc5;SR             -3.141593              0.347655
# 4       mc5;SR             -0.000000              0.137277
# ...        ...                   ...                   ...
# 18193   mc3;SO             -3.141593              1.303866
# 18194   mc3;SO              0.000000             -1.070015
# 18195   mc0;SO             -3.141593              1.267531
# 18196   mc4;SO             -0.000000              0.815231
# 18197   mc5;SO             -0.000000              0.121097
#
#        rotation_angle_zaxis synapse_class           x           y  \
# 0                 -0.000000           INH  409.446689  525.218483
# 1                 -3.141593           INH  692.961402  511.187277
# 2                 -3.141593           INH  624.142630  520.641475
# 3                 -3.141593           INH  430.543380  411.999965
# 4                 -0.000000           INH  427.936977  302.239247
# ...                     ...           ...         ...         ...
# 18193             -3.141593           INH  771.381002   37.274531
# 18194              0.000000           INH  666.970306   58.551145
# 18195             -3.141593           INH  505.811537  130.131875
# 18196             -0.000000           INH  -68.542249   57.960736
# 18197             -0.000000           INH  222.667008   90.924602
#
#                  z  @dynamics:holding_current  @dynamics:threshold_current
# 0      1074.146619                   0.028962                     0.224609
# 1       573.179832                   0.028962                     0.224609
# 2       976.924721                   0.028962                     0.224609
# 3      1180.185218                   0.005140                     0.341797
# 4      1013.453517                   0.004947                     0.341797
# ...            ...                        ...                          ...
# 18193   231.992286                  -0.011643                     0.302734
# 18194   396.539067                  -0.044198                     0.449219
# 18195   182.700052                  -0.044335                     0.439453
# 18196   940.564725                  -0.001224                     0.371094
# 18197   902.060798                  -0.057650                     0.527344
#
# [18198 rows x 17 columns]

# %%
mtypes = cells.property_values(Cell.MTYPE)

# %%
mtypes = list(mtypes)

# %%
i = 0
mntypes = {}
for mn in list(mtypes):
    mntypes[mn] = i
    i+=1

# %%
mtypes
# Out:
# ['SP_Ivy',
#  'SP_CCKBC',
#  'SP_BS',
#  'SO_BS',
#  'SO_BP',
#  'SO_OLM',
#  'SO_Tri',
#  'SP_PVBC',
#  'SR_SCA',
#  'SLM_PPA',
#  'SP_AA',
#  'SP_PC']

# %%
mntypes['SP_PC'] = 0
mntypes['SP_Ivy'] = 11
mtypes[0] = 'SP_PC'
mtypes[11] = 'SP_Ivy'

# %%
mntypes['ca3'] = 12
mtypes.append('ca3')

# %%
nodeprex = []
nodeprez = []       
nodeprey = [] 
nodepremtype = []    
for gid in range(18198):
#     if nodesinfo['region'][gid][0:3]!='mc9':    
    if nodesinfo['mtype'][gid]=='SP_PC':     
        nodeprex.append(nodesinfo['x'][gid])
        nodeprey.append(nodesinfo['y'][gid])
        nodeprez.append(nodesinfo['z'][gid])
        nodepremtype.append(mntypes[nodesinfo['mtype'][gid]])
        
for gid in range(18198):
    if nodesinfo['mtype'][gid]!='SP_PC':     
        nodeprex.append(nodesinfo['x'][gid])
        nodeprey.append(nodesinfo['y'][gid])
        nodeprez.append(nodesinfo['z'][gid])
        nodepremtype.append(mntypes[nodesinfo['mtype'][gid]])

# %%
nodeprex.append(nodesinfo['x'][gid])
nodeprey.append(nodesinfo['y'][gid])
nodeprez.append(nodesinfo['z'][gid])
nodepremtype.append(mntypes['ca3'])

# %%
mtypes
# Out:
# ['SP_PC',
#  'SP_CCKBC',
#  'SP_BS',
#  'SO_BS',
#  'SO_BP',
#  'SO_OLM',
#  'SO_Tri',
#  'SP_PVBC',
#  'SR_SCA',
#  'SLM_PPA',
#  'SP_AA',
#  'SP_Ivy',
#  'ca3']

# %%
# plot the results
fig=plt.figure(figsize=(8,8))
plt.scatter(nodeprex,nodeprey, lw=0.05, s=18,
            c=nodepremtype, cmap=plt.cm.get_cmap('gnuplot', 12))

cbar=plt.colorbar()              # the mystery step
cbar.set_ticks([n+0.5 for n in range(12)])
cbar.set_ticklabels(mtypes)
plt.clim(0, 12)
plt.grid(False)
layer_heights = (0, 170, 230, 510, 660)
heights = (100, 210, 365, 570)
layers = ('SO', 'SP', 'SR', 'SLM')
plt.hlines(layer_heights, np.min(nodeprex)-110, np.max(nodeprex), linestyle='--', colors='r')
for layer, height in zip(layers, heights):
    plt.text(np.min(nodeprex)-110, height, layer, fontsize=14, color='r')
plt.xlabel('x', fontsize=12)
plt.ylabel('y', fontsize=12)
plt.yticks([0, 170, 230, 510, 660])
plt.xlim(-240,960)
plt.ylim(0,600)
plt.xticks([-240,0,240,480,720,960])
plt.xticks(fontsize=12);
plt.yticks(fontsize=12);
plt.gca().invert_yaxis();

# %%
# plot the results
fig=plt.figure(figsize=(12,10))
plt.scatter(nodeprex,nodeprez, lw=0.05, s=22,
            c=nodepremtype, cmap=plt.cm.get_cmap('gnuplot', 11))

cbar=plt.colorbar()              # the mystery step
cbar.set_ticks([n+0.5 for n in range(12)])
cbar.set_ticklabels(mtypes)
plt.clim(0, 12)
plt.grid(False)
plt.xlabel('x', fontsize=12)
plt.ylabel('z', fontsize=12)
# plt.xlim(np.min(nodepre2)-0.5,np.min(nodepre2)+400.5)
# plt.ylim(np.min(nodepre2)-0.5,np.min(nodepre2)+400.5)
#plt.xticks(fontsize=14, rotation=90)
# plt.xlim(230,490)
plt.xticks(fontsize=12);
plt.yticks(fontsize=12);

# %%
print(np.max(nodeprex)-np.min(nodeprex),np.max(nodeprey)-np.min(nodeprey),np.max(nodeprez)-np.min(nodeprez))
print(np.max(nodeprex),np.min(nodeprex),np.max(nodeprey),np.min(nodeprey),np.max(nodeprez),np.min(nodeprez))
# Out:
# 1197.7552169295802 525.1244422217203 1259.5194865417625
# 958.5717319660093 -239.1834849635709 525.2184832175008 0.09404099578042668 1259.7976867542293 0.27820021246686366

# %%
# each column area
area = (3*np.sqrt(3)*240**2)/2 # six triag l = 240, h =  240*np.sqrt(3)/2
diam = 2*np.sqrt(area/np.pi) #equiv circle
diam
# Out:
# 436.5080368764948

# %%
list(nodesinfo)
# Out:
# ['etype',
#  'layer',
#  'model_template',
#  'model_type',
#  'morph_class',
#  'morphology',
#  'mtype',
#  'region',
#  'rotation_angle_xaxis',
#  'rotation_angle_yaxis',
#  'rotation_angle_zaxis',
#  'synapse_class',
#  'x',
#  'y',
#  'z',
#  '@dynamics:holding_current',
#  '@dynamics:threshold_current']

# %%
most_central_10_SP_PC = [11617, 6393, 6789, 6243, 13513, 14311, 9397, 3699, 12245, 12001]
most_central_10_SP_PC = most_central_10_SP_PC - np.ones_like(most_central_10_SP_PC)

# most_central_10_SP_PC = range(18198)
most_central_10_SP_PC = range(35,40)
Morpholist = []
hoclist = []
for gid in most_central_10_SP_PC:
    MorphoName = MorphologyPath + nodesinfo['morphology'][gid] + '.swc'
    hocName = METypePath + nodesinfo['model_template'][gid][4:] + '.hoc'
    cellName = nodesinfo['model_template'][gid][4:]  
    mcName = nodesinfo['region'][gid][:3]  
    layerName = nodesinfo['region'][gid][4:]  
    print('%s\n %s %.2f %.2f %.2f' % (nodesinfo['model_template'][gid],nodesinfo['region'][gid],nodesinfo['x'][gid],nodesinfo['y'][gid],nodesinfo['z'][gid]))
    
#     if cellName not in hoclist:
#         hoclist.append(cellName)   
        
#     if nodesinfo['morphology'][gid] not in Morpholist:
#         Morpholist.append(nodesinfo['morphology'][gid])
# Out:
# hoc:CA1_int_cAC_990611HP2_2019032816214
#  mc5;SR 379.41 447.99 956.30
# hoc:CA1_pyr_cACpyr_oh140807_A0_idJ_2019032814272
#  mc0;SP 128.92 222.86 209.59
# hoc:CA1_pyr_cACpyr_mpg141216_A_idA_2019030513333
#  mc5;SP 299.64 184.32 910.95
# hoc:CA1_pyr_cACpyr_oh140807_A0_idF_2019030511545
#  mc0;SP 405.05 224.33 94.36
# hoc:CA1_pyr_cACpyr_mpg141216_A_idA_2019030513333
#  mc3;SP 720.95 207.81 557.53

# %%
print('hoclist size =',np.size(hoclist))
print('Morpholist size =',np.size(Morpholist))
# import os # cp only the 646 used morphos # Morpholist2 = cells.property_values(Cell.MORPHOLOGY)

# for MorphoName in Morpholist:
#     mfile = '/home/fernando/CA1__/data-bbp/20191017/morphologies/swc/' + MorphoName + '.swc'
#     outfile = MorphologyPath + MorphoName + '.swc'
#     os.popen("cp {0} {1}".format(mfile, outfile))
#     print(outfile)
# Out:
# hoclist size = 36
# Morpholist size = 646

# %%
from neuron import h
from neuron.units import mV, ms
import plotly
import plotly.graph_objects as go
h.load_file("import3d.hoc")
h.load_file("stdrun.hoc")

gid = 6393 - 1

MorphoName = MorphologyPath + nodesinfo['morphology'][gid] + '.swc'

cellmorpho = h.Import3d_SWC_read()
cellmorpho.input(MorphoName)
i3d = h.Import3d_GUI(cellmorpho, False)
i3d.instantiate(None)

ps = h.PlotShape(False)
ps.variable("v")
ps.scale(-70, 40)
fig = ps.plot(plotly, line={"width": 4})

# fig.show()

# %%
mcName = []
for gid in range(cells.size):
    mcName.append(int(nodesinfo['region'][gid][2:3]))  
plt.hist(mcName, bins = 7)
# Out:
# (array([2553., 2694., 2484., 2633., 2595., 2664., 2575.]),
#  array([0.        , 0.85714286, 1.71428571, 2.57142857, 3.42857143,
#         4.28571429, 5.14285714, 6.        ]),
#  <BarContainer object of 7 artists>)

# %% [markdown]
# ## Net info

# %%
# data-bbp/20191017/sonata/edges ~ 7.4 Gb 
circuit_path2 = '/home/fernando/CA1__/data-bbp/20191017/circuit_config.json'
circuit2 = Circuit(circuit_path2)
conn = circuit2.edges["hippocampus_neurons__hippocampus_neurons__chemical"]
print(list(circuit.nodes))
print(list(circuit2.edges))
# Out:
# ['hippocampus_neurons', 'hippocampus_projections']
# ['hippocampus_neurons__hippocampus_neurons__chemical', 'hippocampus_projections__hippocampus_neurons__chemical']

# %%
# cells = circuit.nodes["hippocampus_neurons"]
# conn = circuit.edges["hippocampus_neurons__hippocampus_neurons__chemical"]
# proj_cells =circuit.nodes["hippocampus_projections"]
# proj_conn =circuit.edges["hippocampus_projections__hippocampus_neurons__chemical"]
print(cells.size)
print(conn.size)
# Out:
# 18198
# 19698045

# %%
pre_mtype = 'SP_PC'
post_mtype = 'SP_PVBC' 
print(pre_mtype, post_mtype)
it = conn.iter_connections(pre_mtype, post_mtype, return_edge_count=True)
nodepre = np.array([p[0] for p in itertools.islice(it, 10000000)])
it = conn.iter_connections(pre_mtype, post_mtype, return_edge_count=True)
nodepost = np.array([p[1] for p in itertools.islice(it, 10000000)])
it = conn.iter_connections(pre_mtype, post_mtype, return_edge_count=True)
synnumber = np.array([p[2] for p in itertools.islice(it, 10000000)])

print(np.size(synnumber),np.sum(synnumber),np.mean(synnumber),np.std(synnumber))
print(np.max(nodepre)-np.min(nodepre)+1,np.max(nodepost)-np.min(nodepost)+1)
print(np.min(nodepre),np.max(nodepre),np.min(nodepost),np.max(nodepost))
# Out:
# SP_PC SP_PVBC
# 253092 1245510 4.921174908728842 2.508239893425534
# 16860 299
# 36 16895 16896 17194

# %%
fig=plt.figure(figsize=(24, 6))
plt.plot(nodepre,nodepost,'.', color='black', alpha=1.0)
plt.grid(False)
plt.xlabel('pre', fontsize=12)
plt.ylabel('post', fontsize=12)
plt.xlim(np.min(nodepre)-0.5,np.min(nodepre)+1296.5)
plt.ylim(np.min(nodepost)-0.5,np.max(nodepost)+0.5)
#plt.xticks(fontsize=14, rotation=90)
plt.xticks(fontsize=12);
plt.yticks(fontsize=12);

# fig.savefig('Adj.png')

# %%
pre_mtype = 'SP_PC'
post_mtype = 'SP_PC' 
print(pre_mtype, post_mtype)
it = conn.iter_connections(pre_mtype, post_mtype, return_edge_count=True)
nodepre = np.array([p[0] for p in itertools.islice(it, 10000000)])
it = conn.iter_connections(pre_mtype, post_mtype, return_edge_count=True)
nodepost = np.array([p[1] for p in itertools.islice(it, 10000000)])
it = conn.iter_connections(pre_mtype, post_mtype, return_edge_count=True)
synnumber = np.array([p[2] for p in itertools.islice(it, 10000000)])

print(np.size(synnumber),np.sum(synnumber),np.mean(synnumber),np.std(synnumber))
print(np.max(nodepre)-np.min(nodepre)+1,np.max(nodepost)-np.min(nodepost)+1)
print(np.min(nodepre),np.max(nodepre),np.min(nodepost),np.max(nodepost))
# Out:
# SP_PC SP_PC
# 2783388 3553062 1.2765241497053232 0.6550574580415391
# 16860 16860
# 36 16895 36 16895

# %%
# plot the results
fig=plt.figure(figsize=(12, 10))
plt.scatter(nodepre,nodepost, lw=0.1,
            c=synnumber, cmap=plt.cm.get_cmap('gnuplot', 4))
plt.colorbar(ticks=range(6), label='synnumber')
plt.clim(0.5, 4.5)
plt.grid(False)
plt.xlabel('pre', fontsize=12)
plt.ylabel('post', fontsize=12)
plt.xlim(np.min(nodepre)-0.5,np.min(nodepre)+400.5)
plt.ylim(np.min(nodepre)-0.5,np.min(nodepre)+400.5)
#plt.xticks(fontsize=14, rotation=90)
plt.xticks(fontsize=12);
plt.yticks(fontsize=12);

# %%
for gid in nodepre[:4]:
    print('%d %s %s %.2f %.2f %.2f' % (gid,nodesinfo['mtype'][gid],nodesinfo['region'][gid],nodesinfo['x'][gid],nodesinfo['y'][gid],nodesinfo['z'][gid]))
print('')
for gid in nodepost[:4]:
    print('%d %s %s %.2f %.2f %.2f' % (gid,nodesinfo['mtype'][gid],nodesinfo['region'][gid],nodesinfo['x'][gid],nodesinfo['y'][gid],nodesinfo['z'][gid]))
print('')
for gid in nodepre[253092-4:253092+1]:
    print('%d %s %s %.2f %.2f %.2f' % (gid,nodesinfo['mtype'][gid],nodesinfo['region'][gid],nodesinfo['x'][gid],nodesinfo['y'][gid],nodesinfo['z'][gid]))
print('')
for gid in nodepost[253092-4:253092+1]:
    print('%d %s %s %.2f %.2f %.2f' % (gid,nodesinfo['mtype'][gid],nodesinfo['region'][gid],nodesinfo['x'][gid],nodesinfo['y'][gid],nodesinfo['z'][gid]))
# Out:
# 425 SP_PC mc4;SP 92.11 212.29 962.25
# 674 SP_PC mc0;SP 173.86 229.53 178.24
# 1883 SP_PC mc0;SP 418.88 224.12 92.80
# 2289 SP_PC mc1;SP 144.55 214.23 267.54
#
# 36 SP_PC mc0;SP 128.92 222.86 209.59
# 36 SP_PC mc0;SP 128.92 222.86 209.59
# 36 SP_PC mc0;SP 128.92 222.86 209.59
# 36 SP_PC mc0;SP 128.92 222.86 209.59
#
# 13110 SP_PC mc2;SP 278.24 205.41 805.37
# 13240 SP_PC mc2;SP 486.34 171.36 615.20
# 13263 SP_PC mc4;SP -15.75 221.85 1038.10
# 13307 SP_PC mc5;SP 390.22 182.53 1203.73
# 13315 SP_PC mc2;SP 175.61 199.02 647.10
#
# 1574 SP_PC mc5;SP 316.06 186.42 1176.53
# 1574 SP_PC mc5;SP 316.06 186.42 1176.53
# 1574 SP_PC mc5;SP 316.06 186.42 1176.53
# 1574 SP_PC mc5;SP 316.06 186.42 1176.53
# 1574 SP_PC mc5;SP 316.06 186.42 1176.53

# %%
def distance3D(gidpre,gidpost):
    return np.sqrt(np.power(nodesinfo['x'][gidpre]-nodesinfo['x'][gidpost],2)+np.power(nodesinfo['y'][gidpre]-nodesinfo['y'][gidpost],2)+np.power(nodesinfo['z'][gidpre]-nodesinfo['z'][gidpost],2))

# %%
i=0
mcout = {}
for gid in range(7):
    mcout[gid] = {}
    for gidpost in range(7):
        mcout[gid][gidpost] = 0

distance_3D = []           
nodeprex = []
nodepostx = []   
nodeprez = []
nodepostz = []         
nodeprey = []
nodeposty = []   
for numsyn in synnumber:
    gid = nodepre[i]
    gidpost = nodepost[i]
    mcout[int(nodesinfo['region'][gid][2:3])][int(nodesinfo['region'][gidpost][2:3])] += 1
    if nodesinfo['region'][gid][0:3]=='mc2':     
        nodeprex.append(nodesinfo['x'][gid])
        nodepostx.append(nodesinfo['x'][gidpost]) 
        nodeprey.append(nodesinfo['y'][gid])
        nodeposty.append(nodesinfo['y'][gidpost])
        nodeprez.append(nodesinfo['z'][gid])
        nodepostz.append(nodesinfo['z'][gidpost])
        distance_3D.append(distance3D(gid,gidpost))  
    
#     if nodesinfo['region'][gid][0:3] != nodesinfo['region'][gidpost][0:3]:
#     if distance3D(gid,gidpost)<50.0 and nodesinfo['region'][gid][0:3]=='mc2' and nodesinfo['region'][gidpost][0:3]=='mc1':
#         print('%d %s %s %.2f' % (numsyn,nodesinfo['region'][gid][0:3],nodesinfo['region'][gidpost][0:3],distance3D(gid,gidpost)))
#         distance_3D.append(distance3D(gid,gidpost))
        
    i+=1
# print(mc2in,mc2out)

# %%
harvest = np.array([[0.8, 2.4, 2.5, 3.9, 0.0, 4.0, 0.0],
                    [2.4, 0.0, 4.0, 1.0, 2.7, 0.0, 0.0],
                    [1.1, 2.4, 0.8, 4.3, 1.9, 4.4, 0.0],
                    [0.6, 0.0, 0.3, 0.0, 3.1, 0.0, 0.0],
                    [0.7, 1.7, 0.6, 2.6, 2.2, 6.2, 0.0],
                    [1.3, 1.2, 0.0, 0.0, 0.0, 3.2, 5.1],
                    [0.1, 2.0, 0.0, 1.4, 0.0, 1.9, 6.3]])
for gid in range(7):
    for gidpost in range(7):
        harvest[gid][gidpost] = float(mcout[gid][gidpost])

plt.imshow(harvest, cmap=plt.cm.get_cmap('hot', 5))
plt.colorbar()
plt.clim(0,150000)

# %%
print(np.size(nodepre),np.size(nodeprex),100*np.size(nodeprex)/np.size(nodepre))
# Out:
# 2783388 468474 16.831070623283566

# %%
fig=plt.figure(figsize=(14,4))
plt.hist(distance_3D, bins=100);

# %%
print(np.max(nodepostz)-np.min(nodepostz),np.max(nodepostx)-np.min(nodepostx))
# Out:
# 1259.2435193450285 1197.7552169295802

# %%
from matplotlib import colors
fig=plt.figure(figsize=(6,6))
plt.hist2d(nodepostz,nodepostx, bins=(63,60), norm=colors.LogNorm());

# %%
# plot the results
fig=plt.figure(figsize=(14,12))
# plt.scatter(nodeprez,nodeprex, lw=0.05,
#             c=distance_3D, cmap=plt.cm.get_cmap('gnuplot', 4))
plt.scatter(nodepostz,nodepostx, lw=0.05,
            c=distance_3D, cmap=plt.cm.get_cmap('gnuplot', 4))
# plt.colorbar(ticks=range(4), label='synnumber')
plt.colorbar(label='synnumber')
# plt.clim(0.5, 200.5)
plt.grid(False)
plt.xlabel('pre', fontsize=12)
plt.ylabel('post', fontsize=12)
# plt.xlim(np.min(nodepre2)-0.5,np.min(nodepre2)+400.5)
# plt.ylim(np.min(nodepre2)-0.5,np.min(nodepre2)+400.5)
#plt.xticks(fontsize=14, rotation=90)
plt.xticks(fontsize=12);
plt.yticks(fontsize=12);

# %% [markdown]
# ## Only mc2PC:mc2PC

# %%
i=0
mcout = {}
for gid in range(7):
    mcout[gid] = {}
    for gidpost in range(7):
        mcout[gid][gidpost] = 0

distance_3D = []             
nodepre2 = []
nodepost2 = []           
nodeprex = []
nodepostx = []   
nodeprez = []
nodepostz = []         
nodeprey = []
nodeposty = []   
for numsyn in synnumber:
    gid = nodepre[i]
    gidpost = nodepost[i]
    mcout[int(nodesinfo['region'][gid][2:3])][int(nodesinfo['region'][gidpost][2:3])] += 1
    if nodesinfo['region'][gid][0:3]=='mc2' and nodesinfo['region'][gidpost][0:3]=='mc2':   
        nodepre2.append(gid)
        nodepost2.append(gidpost)    
        nodeprex.append(nodesinfo['x'][gid])
        nodepostx.append(nodesinfo['x'][gidpost]) 
        nodeprey.append(nodesinfo['y'][gid])
        nodeposty.append(nodesinfo['y'][gidpost])
        nodeprez.append(nodesinfo['z'][gid])
        nodepostz.append(nodesinfo['z'][gidpost])
        distance_3D.append(distance3D(gid,gidpost))              
    i+=1

# %%
print(np.size(nodepre),np.size(nodeprex),100*np.size(nodeprex)/np.size(nodepre))
# Out:
# 2783388 149586 5.374241751419493

# %%
fig=plt.figure(figsize=(14,4))
plt.hist(distance_3D, bins=100);

# %%
print(np.max(nodepostz)-np.min(nodepostz),np.max(nodepostx)-np.min(nodepostx))
# Out:
# 419.6228977761445 470.18203023229825

# %%
# plot the results
fig=plt.figure(figsize=(14,12))
# plt.scatter(nodeprez,nodeprex, lw=0.05,
#             c=distance_3D, cmap=plt.cm.get_cmap('gnuplot', 4))
plt.scatter(nodepostz,nodepostx, lw=0.05,
            c=nodepost2, cmap=plt.cm.get_cmap('gnuplot', 7))
# plt.colorbar(ticks=range(4), label='synnumber')
plt.colorbar(label='synnumber')
# plt.clim(0.5, 200.5)
plt.grid(False)
plt.xlabel('pre', fontsize=12)
plt.ylabel('post', fontsize=12)
# plt.xlim(np.min(nodepre2)-0.5,np.min(nodepre2)+400.5)
# plt.ylim(np.min(nodepre2)-0.5,np.min(nodepre2)+400.5)
#plt.xticks(fontsize=14, rotation=90)
plt.xticks(fontsize=12);
plt.yticks(fontsize=12);

# %%
# Out:
# (array([2553., 2694., 2484., 2633., 2595., 2664., 2575.]),
#  array([0.        , 0.85714286, 1.71428571, 2.57142857, 3.42857143,
#         4.28571429, 5.14285714, 6.        ]),
#  <BarContainer object of 7 artists>)

# %%
i=0
for gid in range(np.min(nodepre),np.max(nodepre)+1):
    for gidpost in range(np.min(nodepost),np.max(nodepost)+1):
        if distance3D(gid,gidpost)<50.0:
            i+=1
i
# Out:
# 27355

# %%
np.size(distance_3D)
# Out:
# 5470

# %%
mtypes = cells.property_values(Cell.MTYPE)
model_mean = pd.DataFrame(index=mtypes, columns=mtypes, dtype=float)
model_std = pd.DataFrame(index=mtypes, columns=mtypes, dtype=float)

# %%
nsample = 1000
def sample_nsyn(pre, post):
    it = conn.iter_connections(pre, post, return_edge_count=True)
    return np.array([p[2] for p in itertools.islice(it, nsample)])

# %%
for pre_mtype in mtypes:
    for post_mtype in mtypes:
        data = sample_nsyn(
            pre={Cell.MTYPE: pre_mtype, Cell.REGION: {'$regex': 'mc2.*'}},
            post={Cell.MTYPE: post_mtype}
        )
        if len(data) != 0:
            model_mean[post_mtype][pre_mtype] = data.mean()
            model_std[post_mtype][pre_mtype] = data.std()

# %%
model_mean
# Out:
#             SR_SCA  All  SLM_PPA     SP_BS     SO_BP  SP_CCKBC     SP_AA  \
# SR_SCA    4.200000  NaN      NaN  1.304348  1.000000  1.142857  1.090909
# All            NaN  NaN      NaN       NaN       NaN       NaN       NaN
# SLM_PPA        NaN  NaN      NaN       NaN       NaN       NaN       NaN
# SP_BS     2.210526  NaN      NaN  4.246753  2.222222  1.800000  2.870968
# SO_BP          NaN  NaN      NaN       NaN       NaN       NaN       NaN
# SP_CCKBC  1.285714  NaN      NaN  4.780000  2.666667  1.400000  1.712644
# SP_AA          NaN  NaN      NaN       NaN       NaN       NaN       NaN
# SP_PC     2.610000  NaN      NaN  3.350000  2.580000  3.020000  3.770000
# SO_BS     1.833333  NaN      NaN  2.312500  1.500000  1.541667  1.545455
# SP_PVBC   1.088889  NaN      NaN  2.870000  1.062500  1.200000  1.260000
# SO_OLM    1.000000  NaN      NaN  1.000000       NaN  2.973684  3.466667
# SP_Ivy    2.833333  NaN      1.0  5.830000  1.275000  2.670000  3.140000
# SO_Tri    1.470588  NaN      NaN  3.173913  2.000000  1.348485  2.000000
#
#           SP_PC     SO_BS   SP_PVBC    SO_OLM    SP_Ivy    SO_Tri
# SR_SCA     5.25  1.636364  1.436782  1.111111  1.258427  1.000000
# All         NaN       NaN       NaN       NaN       NaN       NaN
# SLM_PPA     NaN       NaN       NaN       NaN       NaN       NaN
# SP_BS      5.99  2.153846  4.240000  1.603774  3.880000  2.655172
# SO_BP       NaN       NaN       NaN       NaN       NaN       NaN
# SP_CCKBC   8.64  1.750000  4.160000  1.272727  3.210000  3.073171
# SP_AA      7.24       NaN       NaN       NaN       NaN       NaN
# SP_PC      1.28  6.330000  5.250000  2.810000  3.660000  4.030000
# SO_BS      6.50       NaN  3.204545  1.600000  2.486111  1.333333
# SP_PVBC   10.64  1.375000  2.370000  1.326087  1.900000  1.640000
# SO_OLM     9.31  1.000000  3.540000  1.000000  1.333333  1.000000
# SP_Ivy    14.37  1.368421  6.130000  1.246154  4.700000  3.470000
# SO_Tri     6.83  3.000000  3.510000  3.000000  2.940000  3.050000

# %%
for gidpre in range(0,7,2):
    print(gidpre,nodesinfo['region'][gidpre][0:3],nodesinfo['mtype'][gidpre])
    for gid in conn.afferent_nodes(gidpre):
        print('  ',gid,nodesinfo['region'][gid][0:3],nodesinfo['mtype'][gid])
# Out:
# 0 mc5 SLM_PPA
#    18041 mc5 SO_OLM
#    18069 mc5 SO_OLM
#    18081 mc5 SO_OLM
#    18091 mc5 SO_OLM
#    18095 mc5 SO_OLM
#    18115 mc6 SO_OLM
#    18145 mc1 SO_BS
# 2 mc6 SLM_PPA
#    0 mc5 SLM_PPA
#    17477 mc6 SP_BS
#    18066 mc6 SO_OLM
#    18078 mc6 SO_OLM
#    18082 mc5 SO_OLM
#    18117 mc5 SO_OLM
#    18190 mc6 SO_BP
#    18191 mc6 SO_BP
# 4 mc5 SR_SCA
#    5 mc5 SR_SCA
#    7 mc5 SR_SCA
#    16 mc5 SR_SCA
#    19 mc6 SR_SCA
#    28 mc5 SR_SCA
#    29 mc6 SR_SCA
#    32 mc5 SR_SCA
#    33 mc6 SR_SCA
#    35 mc5 SR_SCA
#    46 mc5 SP_PC
#    121 mc5 SP_PC
#    152 mc2 SP_PC
#    156 mc2 SP_PC
#    157 mc5 SP_PC
#    178 mc4 SP_PC
#    207 mc2 SP_PC
#    212 mc5 SP_PC
#    220 mc5 SP_PC
#    253 mc5 SP_PC
#    258 mc6 SP_PC
#    262 mc2 SP_PC
#    274 mc0 SP_PC
#    281 mc0 SP_PC
#    287 mc5 SP_PC
#    294 mc5 SP_PC
#    349 mc2 SP_PC
#    361 mc6 SP_PC
#    383 mc4 SP_PC
#    384 mc4 SP_PC
#    480 mc5 SP_PC
#    486 mc6 SP_PC
#    502 mc5 SP_PC
#    511 mc2 SP_PC
#    526 mc5 SP_PC
#    532 mc5 SP_PC
#    552 mc4 SP_PC
#    560 mc2 SP_PC
#    572 mc6 SP_PC
#    575 mc3 SP_PC
#    590 mc5 SP_PC
#    598 mc5 SP_PC
#    628 mc5 SP_PC
#    629 mc4 SP_PC
#    636 mc5 SP_PC
#    640 mc5 SP_PC
#    642 mc5 SP_PC
#    666 mc4 SP_PC
#    668 mc2 SP_PC
#    723 mc5 SP_PC
#    731 mc5 SP_PC
#    737 mc2 SP_PC
#    743 mc5 SP_PC
#    768 mc6 SP_PC
#    785 mc5 SP_PC
#    799 mc5 SP_PC
#    800 mc2 SP_PC
#    824 mc6 SP_PC
#    866 mc5 SP_PC
#    901 mc6 SP_PC
#    926 mc5 SP_PC
#    927 mc5 SP_PC
#    1000 mc5 SP_PC
#    1036 mc5 SP_PC
#    1056 mc5 SP_PC
#    1070 mc6 SP_PC
#    1101 mc2 SP_PC
#    1169 mc2 SP_PC
#    1188 mc4 SP_PC
#    1195 mc4 SP_PC
#    1223 mc1 SP_PC
#    1227 mc6 SP_PC
#    1279 mc3 SP_PC
#    1327 mc2 SP_PC
#    1356 mc5 SP_PC
#    1373 mc4 SP_PC
#    1382 mc5 SP_PC
#    1439 mc4 SP_PC
#    1457 mc5 SP_PC
#    1537 mc5 SP_PC
#    1550 mc2 SP_PC
#    1562 mc6 SP_PC
#    1564 mc1 SP_PC
#    1590 mc2 SP_PC
#    1650 mc5 SP_PC
#    1682 mc6 SP_PC
#    1731 mc5 SP_PC
#    1737 mc2 SP_PC
#    1758 mc5 SP_PC
#    1766 mc6 SP_PC
#    1767 mc5 SP_PC
#    1786 mc2 SP_PC
#    1848 mc6 SP_PC
#    1867 mc5 SP_PC
#    1917 mc5 SP_PC
#    1970 mc5 SP_PC
#    2017 mc5 SP_PC
#    2033 mc5 SP_PC
#    2068 mc4 SP_PC
#    2090 mc1 SP_PC
#    2113 mc6 SP_PC
#    2124 mc5 SP_PC
#    2135 mc5 SP_PC
#    2146 mc6 SP_PC
#    2165 mc4 SP_PC
#    2199 mc5 SP_PC
#    2210 mc2 SP_PC
#    2224 mc5 SP_PC
#    2237 mc5 SP_PC
#    2238 mc2 SP_PC
#    2252 mc5 SP_PC
#    2291 mc5 SP_PC
#    2333 mc5 SP_PC
#    2360 mc1 SP_PC
#    2367 mc5 SP_PC
#    2393 mc2 SP_PC
#    2429 mc5 SP_PC
#    2436 mc4 SP_PC
#    2471 mc5 SP_PC
#    2474 mc5 SP_PC
#    2482 mc2 SP_PC
#    2498 mc5 SP_PC
#    2513 mc3 SP_PC
#    2543 mc4 SP_PC
#    2599 mc5 SP_PC
#    2600 mc5 SP_PC
#    2604 mc6 SP_PC
#    2619 mc6 SP_PC
#    2630 mc5 SP_PC
#    2647 mc5 SP_PC
#    2706 mc6 SP_PC
#    2720 mc5 SP_PC
#    2724 mc6 SP_PC
#    2727 mc6 SP_PC
#    2739 mc2 SP_PC
#    2767 mc5 SP_PC
#    2801 mc6 SP_PC
#    2804 mc4 SP_PC
#    2807 mc4 SP_PC
#    2813 mc5 SP_PC
#    2891 mc3 SP_PC
#    2900 mc4 SP_PC
#    2945 mc4 SP_PC
#    2954 mc6 SP_PC
#    2974 mc5 SP_PC
#    2978 mc5 SP_PC
#    3002 mc4 SP_PC
#    3011 mc5 SP_PC
#    3030 mc0 SP_PC
#    3036 mc4 SP_PC
#    3047 mc5 SP_PC
#    3065 mc5 SP_PC
#    3076 mc5 SP_PC
#    3079 mc5 SP_PC
#    3123 mc5 SP_PC
#    3128 mc5 SP_PC
#    3138 mc6 SP_PC
#    3181 mc5 SP_PC
#    3216 mc5 SP_PC
#    3236 mc2 SP_PC
#    3253 mc4 SP_PC
#    3329 mc2 SP_PC
#    3398 mc6 SP_PC
#    3455 mc6 SP_PC
#    3456 mc5 SP_PC
#    3517 mc2 SP_PC
#    3530 mc6 SP_PC
#    3560 mc4 SP_PC
#    3561 mc5 SP_PC
#    3563 mc6 SP_PC
#    3567 mc5 SP_PC
#    3628 mc4 SP_PC
#    3636 mc5 SP_PC
#    3640 mc5 SP_PC
#    3642 mc6 SP_PC
#    3715 mc4 SP_PC
#    3718 mc3 SP_PC
#    3726 mc5 SP_PC
#    3743 mc6 SP_PC
#    3744 mc2 SP_PC
#    3757 mc5 SP_PC
#    3795 mc5 SP_PC
#    3801 mc5 SP_PC
#    3852 mc4 SP_PC
#    3871 mc5 SP_PC
#    3976 mc4 SP_PC
#    4001 mc5 SP_PC
#    4011 mc2 SP_PC
#    4021 mc5 SP_PC
#    4032 mc6 SP_PC
#    4055 mc5 SP_PC
#    4066 mc6 SP_PC
#    4073 mc2 SP_PC
#    4075 mc1 SP_PC
#    4079 mc2 SP_PC
#    4109 mc5 SP_PC
#    4132 mc5 SP_PC
#    4154 mc6 SP_PC
#    4158 mc2 SP_PC
#    4173 mc5 SP_PC
#    4180 mc5 SP_PC
#    4219 mc4 SP_PC
#    4241 mc2 SP_PC
#    4258 mc4 SP_PC
#    4263 mc3 SP_PC
#    4278 mc5 SP_PC
#    4298 mc2 SP_PC
#    4340 mc6 SP_PC
#    4366 mc5 SP_PC
#    4381 mc4 SP_PC
#    4399 mc2 SP_PC
#    4402 mc5 SP_PC
#    4406 mc4 SP_PC
#    4421 mc5 SP_PC
#    4478 mc6 SP_PC
#    4484 mc2 SP_PC
#    4512 mc6 SP_PC
#    4522 mc6 SP_PC
#    4539 mc5 SP_PC
#    4567 mc5 SP_PC
#    4585 mc4 SP_PC
#    4602 mc3 SP_PC
#    4612 mc5 SP_PC
#    4670 mc5 SP_PC
#    4715 mc2 SP_PC
#    4739 mc5 SP_PC
#    4772 mc6 SP_PC
#    4809 mc5 SP_PC
#    4855 mc2 SP_PC
#    4867 mc1 SP_PC
#    4873 mc5 SP_PC
#    4886 mc1 SP_PC
#    4890 mc5 SP_PC
#    4915 mc2 SP_PC
#    4938 mc4 SP_PC
#    4952 mc6 SP_PC
#    4974 mc4 SP_PC
#    4990 mc5 SP_PC
#    4993 mc6 SP_PC
#    5017 mc2 SP_PC
#    5022 mc4 SP_PC
#    5033 mc6 SP_PC
#    5037 mc5 SP_PC
#    5047 mc3 SP_PC
#    5052 mc5 SP_PC
#    5101 mc2 SP_PC
#    5136 mc6 SP_PC
#    5148 mc4 SP_PC
#    5160 mc2 SP_PC
#    5167 mc6 SP_PC
#    5206 mc6 SP_PC
#    5219 mc5 SP_PC
#    5246 mc6 SP_PC
#    5266 mc5 SP_PC
#    5301 mc4 SP_PC
#    5341 mc5 SP_PC
#    5399 mc2 SP_PC
#    5401 mc5 SP_PC
#    5406 mc5 SP_PC
#    5457 mc5 SP_PC
#    5462 mc4 SP_PC
#    5492 mc5 SP_PC
#    5493 mc5 SP_PC
#    5505 mc5 SP_PC
#    5551 mc5 SP_PC
#    5565 mc6 SP_PC
#    5596 mc2 SP_PC
#    5621 mc1 SP_PC
#    5680 mc2 SP_PC
#    5703 mc2 SP_PC
#    5713 mc5 SP_PC
#    5714 mc5 SP_PC
#    5719 mc5 SP_PC
#    5722 mc5 SP_PC
#    5765 mc2 SP_PC
#    5774 mc1 SP_PC
#    5781 mc6 SP_PC
#    5789 mc5 SP_PC
#    5805 mc5 SP_PC
#    5815 mc5 SP_PC
#    5824 mc5 SP_PC
#    5842 mc1 SP_PC
#    5920 mc2 SP_PC
#    5934 mc6 SP_PC
#    5948 mc4 SP_PC
#    5959 mc5 SP_PC
#    5979 mc2 SP_PC
#    5980 mc5 SP_PC
#    6000 mc5 SP_PC
#    6003 mc5 SP_PC
#    6041 mc5 SP_PC
#    6050 mc4 SP_PC
#    6131 mc4 SP_PC
#    6148 mc6 SP_PC
#    6166 mc0 SP_PC
#    6167 mc5 SP_PC
#    6220 mc5 SP_PC
#    6252 mc6 SP_PC
#    6292 mc0 SP_PC
#    6294 mc4 SP_PC
#    6316 mc5 SP_PC
#    6321 mc5 SP_PC
#    6324 mc5 SP_PC
#    6344 mc5 SP_PC
#    6359 mc5 SP_PC
#    6381 mc5 SP_PC
#    6395 mc5 SP_PC
#    6437 mc5 SP_PC
#    6443 mc2 SP_PC
#    6473 mc2 SP_PC
#    6490 mc5 SP_PC
#    6511 mc4 SP_PC
#    6528 mc5 SP_PC
#    6554 mc5 SP_PC
#    6590 mc5 SP_PC
#    6656 mc6 SP_PC
#    6680 mc5 SP_PC
#    6727 mc5 SP_PC
#    6744 mc1 SP_PC
#    6771 mc4 SP_PC
#    6791 mc6 SP_PC
#    6814 mc2 SP_PC
#    6817 mc5 SP_PC
#    6845 mc5 SP_PC
#    6855 mc2 SP_PC
#    6878 mc5 SP_PC
#    6938 mc6 SP_PC
#    6941 mc5 SP_PC
#    6966 mc6 SP_PC
#    6975 mc2 SP_PC
#    7018 mc5 SP_PC
#    7084 mc5 SP_PC
#    7105 mc6 SP_PC
#    7118 mc1 SP_PC
#    7185 mc6 SP_PC
#    7190 mc3 SP_PC
#    7198 mc2 SP_PC
#    7216 mc5 SP_PC
#    7275 mc2 SP_PC
#    7330 mc0 SP_PC
#    7339 mc1 SP_PC
#    7367 mc2 SP_PC
#    7376 mc5 SP_PC
#    7408 mc2 SP_PC
#    7427 mc2 SP_PC
#    7450 mc6 SP_PC
#    7479 mc4 SP_PC
#    7496 mc4 SP_PC
#    7532 mc5 SP_PC
#    7555 mc6 SP_PC
#    7576 mc5 SP_PC
#    7592 mc5 SP_PC
#    7606 mc5 SP_PC
#    7616 mc5 SP_PC
#    7662 mc3 SP_PC
#    7680 mc5 SP_PC
#    7685 mc5 SP_PC
#    7701 mc5 SP_PC
#    7702 mc0 SP_PC
#    7743 mc6 SP_PC
#    7759 mc3 SP_PC
#    7812 mc5 SP_PC
#    7911 mc5 SP_PC
#    7919 mc4 SP_PC
#    7953 mc5 SP_PC
#    7968 mc1 SP_PC
#    8018 mc5 SP_PC
#    8036 mc5 SP_PC
#    8041 mc2 SP_PC
#    8068 mc2 SP_PC
#    8081 mc5 SP_PC
#    8082 mc2 SP_PC
#    8112 mc5 SP_PC
#    8124 mc3 SP_PC
#    8130 mc4 SP_PC
#    8162 mc3 SP_PC
#    8166 mc6 SP_PC
#    8170 mc2 SP_PC
#    8228 mc6 SP_PC
#    8271 mc5 SP_PC
#    8276 mc5 SP_PC
#    8322 mc5 SP_PC
#    8357 mc4 SP_PC
#    8367 mc5 SP_PC
#    8410 mc5 SP_PC
#    8413 mc5 SP_PC
#    8419 mc4 SP_PC
#    8451 mc5 SP_PC
#    8472 mc5 SP_PC
#    8491 mc5 SP_PC
#    8502 mc4 SP_PC
#    8516 mc4 SP_PC
#    8534 mc2 SP_PC
#    8562 mc6 SP_PC
#    8614 mc6 SP_PC
#    8618 mc5 SP_PC
#    8633 mc4 SP_PC
#    8635 mc5 SP_PC
#    8654 mc2 SP_PC
#    8699 mc4 SP_PC
#    8710 mc5 SP_PC
#    8730 mc5 SP_PC
#    8770 mc2 SP_PC
#    8806 mc1 SP_PC
#    8833 mc2 SP_PC
#    8848 mc6 SP_PC
#    8863 mc6 SP_PC
#    8915 mc5 SP_PC
#    8927 mc5 SP_PC
#    8947 mc5 SP_PC
#    8981 mc5 SP_PC
#    8993 mc2 SP_PC
#    9014 mc5 SP_PC
#    9043 mc6 SP_PC
#    9045 mc4 SP_PC
#    9062 mc6 SP_PC
#    9081 mc4 SP_PC
#    9086 mc5 SP_PC
#    9093 mc2 SP_PC
#    9120 mc5 SP_PC
#    9121 mc4 SP_PC
#    9122 mc6 SP_PC
#    9132 mc2 SP_PC
#    9136 mc5 SP_PC
#    9240 mc5 SP_PC
#    9243 mc5 SP_PC
#    9244 mc2 SP_PC
#    9271 mc3 SP_PC
#    9275 mc2 SP_PC
#    9284 mc4 SP_PC
#    9297 mc5 SP_PC
#    9300 mc5 SP_PC
#    9323 mc5 SP_PC
#    9346 mc4 SP_PC
#    9360 mc3 SP_PC
#    9362 mc5 SP_PC
#    9380 mc2 SP_PC
#    9417 mc6 SP_PC
#    9441 mc6 SP_PC
#    9444 mc2 SP_PC
#    9454 mc5 SP_PC
#    9513 mc6 SP_PC
#    9555 mc4 SP_PC
#    9567 mc5 SP_PC
#    9575 mc5 SP_PC
#    9579 mc5 SP_PC
#    9592 mc4 SP_PC
#    9602 mc0 SP_PC
#    9625 mc5 SP_PC
#    9652 mc5 SP_PC
#    9653 mc5 SP_PC
#    9677 mc4 SP_PC
#    9716 mc2 SP_PC
#    9765 mc5 SP_PC
#    9778 mc5 SP_PC
#    9808 mc4 SP_PC
#    9812 mc3 SP_PC
#    9825 mc5 SP_PC
#    9861 mc5 SP_PC
#    9868 mc5 SP_PC
#    9929 mc6 SP_PC
#    9972 mc3 SP_PC
#    9980 mc5 SP_PC
#    10095 mc4 SP_PC
#    10096 mc5 SP_PC
#    10148 mc5 SP_PC
#    10179 mc4 SP_PC
#    10220 mc5 SP_PC
#    10226 mc6 SP_PC
#    10228 mc6 SP_PC
#    10269 mc6 SP_PC
#    10323 mc6 SP_PC
#    10334 mc5 SP_PC
#    10364 mc2 SP_PC
#    10395 mc5 SP_PC
#    10409 mc6 SP_PC
#    10430 mc1 SP_PC
#    10456 mc5 SP_PC
#    10471 mc6 SP_PC
#    10477 mc5 SP_PC
#    10501 mc5 SP_PC
#    10502 mc5 SP_PC
#    10568 mc6 SP_PC
#    10584 mc5 SP_PC
#    10640 mc0 SP_PC
#    10659 mc4 SP_PC
#    10681 mc5 SP_PC
#    10685 mc4 SP_PC
#    10703 mc2 SP_PC
#    10794 mc2 SP_PC
#    10849 mc2 SP_PC
#    10853 mc4 SP_PC
#    10860 mc5 SP_PC
#    10876 mc5 SP_PC
#    10877 mc6 SP_PC
#    10884 mc3 SP_PC
#    10898 mc5 SP_PC
#    10921 mc5 SP_PC
#    10933 mc5 SP_PC
#    10953 mc2 SP_PC
#    10968 mc5 SP_PC
#    10971 mc0 SP_PC
#    10973 mc5 SP_PC
#    10995 mc4 SP_PC
#    11033 mc6 SP_PC
#    11073 mc4 SP_PC
#    11125 mc5 SP_PC
#    11135 mc3 SP_PC
#    11151 mc5 SP_PC
#    11158 mc5 SP_PC
#    11170 mc5 SP_PC
#    11174 mc4 SP_PC
#    11190 mc4 SP_PC
#    11203 mc4 SP_PC
#    11216 mc5 SP_PC
#    11239 mc4 SP_PC
#    11295 mc4 SP_PC
#    11307 mc5 SP_PC
#    11314 mc4 SP_PC
#    11360 mc4 SP_PC
#    11405 mc5 SP_PC
#    11417 mc2 SP_PC
#    11421 mc6 SP_PC
#    11442 mc2 SP_PC
#    11448 mc5 SP_PC
#    11493 mc1 SP_PC
#    11543 mc5 SP_PC
#    11551 mc3 SP_PC
#    11604 mc2 SP_PC
#    11638 mc5 SP_PC
#    11657 mc5 SP_PC
#    11676 mc5 SP_PC
#    11694 mc5 SP_PC
#    11701 mc5 SP_PC
#    11724 mc5 SP_PC
#    11729 mc5 SP_PC
#    11798 mc4 SP_PC
#    11800 mc3 SP_PC
#    11805 mc4 SP_PC
#    11814 mc4 SP_PC
#    11864 mc2 SP_PC
#    11883 mc4 SP_PC
#    11887 mc5 SP_PC
#    11974 mc5 SP_PC
#    11977 mc2 SP_PC
#    12042 mc3 SP_PC
#    12057 mc2 SP_PC
#    12074 mc5 SP_PC
#    12075 mc5 SP_PC
#    12114 mc5 SP_PC
#    12117 mc5 SP_PC
#    12252 mc5 SP_PC
#    12263 mc4 SP_PC
#    12302 mc5 SP_PC
#    12328 mc2 SP_PC
#    12329 mc2 SP_PC
#    12343 mc2 SP_PC
#    12378 mc5 SP_PC
#    12421 mc6 SP_PC
#    12471 mc6 SP_PC
#    12483 mc5 SP_PC
#    12519 mc5 SP_PC
#    12529 mc5 SP_PC
#    12533 mc3 SP_PC
#    12535 mc2 SP_PC
#    12601 mc5 SP_PC
#    12617 mc6 SP_PC
#    12618 mc2 SP_PC
#    12630 mc5 SP_PC
#    12640 mc5 SP_PC
#    12645 mc5 SP_PC
#    12658 mc5 SP_PC
#    12673 mc0 SP_PC
#    12676 mc5 SP_PC
#    12702 mc5 SP_PC
#    12724 mc5 SP_PC
#    12737 mc6 SP_PC
#    12797 mc4 SP_PC
#    12832 mc6 SP_PC
#    12833 mc5 SP_PC
#    12863 mc2 SP_PC
#    12875 mc6 SP_PC
#    12910 mc5 SP_PC
#    12911 mc4 SP_PC
#    12948 mc6 SP_PC
#    12953 mc1 SP_PC
#    12980 mc5 SP_PC
#    13001 mc5 SP_PC
#    13055 mc6 SP_PC
#    13113 mc5 SP_PC
#    13124 mc5 SP_PC
#    13135 mc4 SP_PC
#    13151 mc2 SP_PC
#    13187 mc6 SP_PC
#    13215 mc5 SP_PC
#    13234 mc2 SP_PC
#    13240 mc2 SP_PC
#    13273 mc4 SP_PC
#    13289 mc4 SP_PC
#    13302 mc2 SP_PC
#    13317 mc0 SP_PC
#    13368 mc5 SP_PC
#    13421 mc6 SP_PC
#    13446 mc6 SP_PC
#    13451 mc5 SP_PC
#    13476 mc4 SP_PC
#    13484 mc6 SP_PC
#    13490 mc5 SP_PC
#    13532 mc2 SP_PC
#    13534 mc5 SP_PC
#    13559 mc5 SP_PC
#    13584 mc0 SP_PC
#    13603 mc5 SP_PC
#    13628 mc1 SP_PC
#    13634 mc2 SP_PC
#    13675 mc5 SP_PC
#    13693 mc5 SP_PC
#    13718 mc6 SP_PC
#    13719 mc6 SP_PC
#    13740 mc6 SP_PC
#    13741 mc5 SP_PC
#    13763 mc3 SP_PC
#    13769 mc5 SP_PC
#    13796 mc1 SP_PC
#    13818 mc5 SP_PC
#    13835 mc0 SP_PC
#    13876 mc2 SP_PC
#    13898 mc6 SP_PC
#    13923 mc1 SP_PC
#    13948 mc5 SP_PC
#    13991 mc5 SP_PC
#    14035 mc6 SP_PC
#    14116 mc6 SP_PC
#    14137 mc6 SP_PC
#    14140 mc5 SP_PC
#    14142 mc2 SP_PC
#    14181 mc2 SP_PC
#    14186 mc2 SP_PC
#    14191 mc5 SP_PC
#    14211 mc6 SP_PC
#    14212 mc4 SP_PC
#    14240 mc5 SP_PC
#    14283 mc5 SP_PC
#    14284 mc6 SP_PC
#    14298 mc2 SP_PC
#    14311 mc4 SP_PC
#    14315 mc5 SP_PC
#    14320 mc2 SP_PC
#    14322 mc2 SP_PC
#    14326 mc6 SP_PC
#    14335 mc5 SP_PC
#    14343 mc5 SP_PC
#    14348 mc4 SP_PC
#    14355 mc6 SP_PC
#    14394 mc5 SP_PC
#    14401 mc6 SP_PC
#    14445 mc6 SP_PC
#    14461 mc2 SP_PC
#    14502 mc2 SP_PC
#    14525 mc5 SP_PC
#    14533 mc5 SP_PC
#    14534 mc4 SP_PC
#    14560 mc5 SP_PC
#    14573 mc5 SP_PC
#    14580 mc5 SP_PC
#    14611 mc5 SP_PC
#    14616 mc5 SP_PC
#    14671 mc6 SP_PC
#    14678 mc6 SP_PC
#    14701 mc6 SP_PC
#    14740 mc4 SP_PC
#    14801 mc5 SP_PC
#    14831 mc5 SP_PC
#    14833 mc2 SP_PC
#    14879 mc5 SP_PC
#    14881 mc5 SP_PC
#    14926 mc6 SP_PC
#    14939 mc6 SP_PC
#    14976 mc5 SP_PC
#    15029 mc2 SP_PC
#    15041 mc6 SP_PC
#    15047 mc6 SP_PC
#    15049 mc4 SP_PC
#    15056 mc5 SP_PC
#    15067 mc2 SP_PC
#    15091 mc1 SP_PC
#    15144 mc2 SP_PC
#    15145 mc5 SP_PC
#    15227 mc5 SP_PC
#    15242 mc6 SP_PC
#    15258 mc5 SP_PC
#    15265 mc5 SP_PC
#    15291 mc3 SP_PC
#    15292 mc6 SP_PC
#    15320 mc5 SP_PC
#    15380 mc2 SP_PC
#    15381 mc5 SP_PC
#    15403 mc3 SP_PC
#    15452 mc4 SP_PC
#    15456 mc2 SP_PC
#    15544 mc2 SP_PC
#    15551 mc5 SP_PC
#    15608 mc2 SP_PC
#    15621 mc5 SP_PC
#    15638 mc5 SP_PC
#    15681 mc2 SP_PC
#    15700 mc2 SP_PC
#    15753 mc5 SP_PC
#    15763 mc1 SP_PC
#    15769 mc6 SP_PC
#    15793 mc6 SP_PC
#    15807 mc6 SP_PC
#    15832 mc5 SP_PC
#    15841 mc6 SP_PC
#    15879 mc6 SP_PC
#    15882 mc5 SP_PC
#    15887 mc3 SP_PC
#    15890 mc5 SP_PC
#    15904 mc5 SP_PC
#    15914 mc5 SP_PC
#    15940 mc6 SP_PC
#    15942 mc6 SP_PC
#    15996 mc5 SP_PC
#    16006 mc2 SP_PC
#    16018 mc5 SP_PC
#    16021 mc3 SP_PC
#    16087 mc5 SP_PC
#    16094 mc5 SP_PC
#    16107 mc5 SP_PC
#    16119 mc2 SP_PC
#    16122 mc5 SP_PC
#    16137 mc6 SP_PC
#    16212 mc5 SP_PC
#    16251 mc0 SP_PC
#    16275 mc5 SP_PC
#    16320 mc5 SP_PC
#    16353 mc4 SP_PC
#    16443 mc5 SP_PC
#    16476 mc5 SP_PC
#    16481 mc5 SP_PC
#    16489 mc2 SP_PC
#    16540 mc5 SP_PC
#    16545 mc6 SP_PC
#    16548 mc1 SP_PC
#    16564 mc4 SP_PC
#    16605 mc4 SP_PC
#    16637 mc6 SP_PC
#    16639 mc5 SP_PC
#    16683 mc5 SP_PC
#    16804 mc5 SP_PC
#    16807 mc6 SP_PC
#    16812 mc5 SP_PC
#    16818 mc6 SP_PC
#    16827 mc5 SP_PC
#    16866 mc6 SP_PC
#    16867 mc2 SP_PC
#    16877 mc2 SP_PC
#    16893 mc6 SP_PC
#    16921 mc6 SP_PVBC
#    16938 mc5 SP_PVBC
#    16983 mc2 SP_PVBC
#    16987 mc5 SP_PVBC
#    16989 mc3 SP_PVBC
#    17012 mc5 SP_PVBC
#    17024 mc6 SP_PVBC
#    17031 mc6 SP_PVBC
#    17038 mc6 SP_PVBC
#    17054 mc5 SP_PVBC
#    17058 mc2 SP_PVBC
#    17082 mc5 SP_PVBC
#    17090 mc6 SP_PVBC
#    17102 mc5 SP_PVBC
#    17103 mc6 SP_PVBC
#    17110 mc6 SP_PVBC
#    17119 mc5 SP_PVBC
#    17127 mc5 SP_PVBC
#    17134 mc6 SP_PVBC
#    17140 mc2 SP_PVBC
#    17143 mc5 SP_PVBC
#    17154 mc6 SP_PVBC
#    17172 mc5 SP_PVBC
#    17189 mc5 SP_PVBC
#    17212 mc6 SP_CCKBC
#    17215 mc6 SP_CCKBC
#    17216 mc5 SP_CCKBC
#    17218 mc5 SP_CCKBC
#    17234 mc5 SP_CCKBC
#    17238 mc2 SP_CCKBC
#    17248 mc5 SP_CCKBC
#    17256 mc5 SP_CCKBC
#    17258 mc5 SP_CCKBC
#    17266 mc5 SP_CCKBC
#    17272 mc5 SP_CCKBC
#    17284 mc5 SP_CCKBC
#    17296 mc5 SP_CCKBC
#    17305 mc2 SP_CCKBC
#    17306 mc6 SP_CCKBC
#    17309 mc5 SP_CCKBC
#    17311 mc5 SP_CCKBC
#    17327 mc5 SP_CCKBC
#    17337 mc6 SP_CCKBC
#    17342 mc5 SP_CCKBC
#    17346 mc6 SP_CCKBC
#    17347 mc5 SP_CCKBC
#    17359 mc6 SP_CCKBC
#    17368 mc5 SP_CCKBC
#    17382 mc5 SP_CCKBC
#    17383 mc5 SP_CCKBC
#    17404 mc6 SP_BS
#    17406 mc5 SP_BS
#    17420 mc6 SP_BS
#    17431 mc5 SP_BS
#    17443 mc5 SP_BS
#    17448 mc6 SP_BS
#    17450 mc5 SP_BS
#    17451 mc5 SP_BS
#    17468 mc5 SP_BS
#    17470 mc5 SP_BS
#    17472 mc5 SP_BS
#    17575 mc2 SP_Ivy
#    17580 mc5 SP_Ivy
#    17581 mc6 SP_Ivy
#    17619 mc5 SP_Ivy
#    17621 mc5 SP_Ivy
#    17651 mc5 SP_Ivy
#    17659 mc5 SP_Ivy
#    17688 mc6 SP_Ivy
#    17690 mc5 SP_Ivy
#    17701 mc5 SP_Ivy
#    17724 mc5 SP_Ivy
#    17725 mc5 SP_Ivy
#    17733 mc5 SP_Ivy
#    17734 mc5 SP_Ivy
#    17737 mc6 SP_Ivy
#    17741 mc6 SP_Ivy
#    17747 mc6 SP_Ivy
#    17764 mc5 SP_Ivy
#    17767 mc5 SP_Ivy
#    17769 mc5 SP_Ivy
#    17774 mc5 SP_Ivy
#    17809 mc5 SP_Ivy
#    17810 mc5 SP_Ivy
#    17814 mc6 SP_Ivy
#    17855 mc5 SP_Ivy
#    17862 mc5 SP_Ivy
#    17866 mc6 SP_Ivy
#    17868 mc5 SP_Ivy
#    17873 mc6 SP_Ivy
#    17894 mc5 SP_Ivy
#    17952 mc5 SP_Ivy
#    17957 mc2 SP_Ivy
#    17962 mc5 SP_Ivy
#    17963 mc5 SP_Ivy
#    17965 mc5 SP_Ivy
#    17972 mc5 SP_Ivy
#    17973 mc2 SP_Ivy
#    17984 mc2 SP_Ivy
#    18013 mc5 SP_Ivy
#    18032 mc5 SP_Ivy
#    18090 mc5 SO_OLM
#    18136 mc4 SO_BS
#    18156 mc5 SO_Tri
#    18159 mc5 SO_Tri
#    18162 mc2 SO_Tri
#    18184 mc5 SO_Tri
#    18191 mc6 SO_BP
# 6 mc0 SR_SCA
#    12 mc3 SR_SCA
#    21 mc2 SR_SCA
#    25 mc2 SR_SCA
#    215 mc2 SP_PC
#    218 mc0 SP_PC
#    234 mc2 SP_PC
#    248 mc3 SP_PC
#    291 mc3 SP_PC
#    319 mc0 SP_PC
#    393 mc0 SP_PC
#    417 mc1 SP_PC
#    456 mc0 SP_PC
#    469 mc6 SP_PC
#    539 mc3 SP_PC
#    604 mc6 SP_PC
#    605 mc3 SP_PC
#    825 mc3 SP_PC
#    893 mc0 SP_PC
#    971 mc3 SP_PC
#    972 mc0 SP_PC
#    1057 mc3 SP_PC
#    1062 mc2 SP_PC
#    1066 mc3 SP_PC
#    1113 mc5 SP_PC
#    1124 mc2 SP_PC
#    1149 mc0 SP_PC
#    1363 mc0 SP_PC
#    1365 mc3 SP_PC
#    1396 mc3 SP_PC
#    1406 mc0 SP_PC
#    1505 mc3 SP_PC
#    1544 mc3 SP_PC
#    1570 mc0 SP_PC
#    1624 mc5 SP_PC
#    1705 mc3 SP_PC
#    1722 mc5 SP_PC
#    1756 mc3 SP_PC
#    1764 mc3 SP_PC
#    1883 mc0 SP_PC
#    1920 mc1 SP_PC
#    2036 mc1 SP_PC
#    2125 mc0 SP_PC
#    2140 mc0 SP_PC
#    2148 mc0 SP_PC
#    2324 mc3 SP_PC
#    2340 mc5 SP_PC
#    2372 mc3 SP_PC
#    2390 mc0 SP_PC
#    2419 mc3 SP_PC
#    2520 mc0 SP_PC
#    2577 mc3 SP_PC
#    2633 mc3 SP_PC
#    2656 mc0 SP_PC
#    2787 mc3 SP_PC
#    2836 mc1 SP_PC
#    2841 mc6 SP_PC
#    2862 mc3 SP_PC
#    2917 mc3 SP_PC
#    3126 mc3 SP_PC
#    3371 mc3 SP_PC
#    3385 mc2 SP_PC
#    3399 mc0 SP_PC
#    3432 mc3 SP_PC
#    3557 mc2 SP_PC
#    3684 mc0 SP_PC
#    3829 mc1 SP_PC
#    3904 mc0 SP_PC
#    3913 mc1 SP_PC
#    3954 mc0 SP_PC
#    4095 mc1 SP_PC
#    4108 mc2 SP_PC
#    4186 mc5 SP_PC
#    4198 mc0 SP_PC
#    4416 mc0 SP_PC
#    4433 mc3 SP_PC
#    4435 mc6 SP_PC
#    4481 mc4 SP_PC
#    4608 mc3 SP_PC
#    4621 mc3 SP_PC
#    4644 mc3 SP_PC
#    4650 mc0 SP_PC
#    4810 mc5 SP_PC
#    4897 mc0 SP_PC
#    4912 mc3 SP_PC
#    4942 mc0 SP_PC
#    5158 mc2 SP_PC
#    5190 mc0 SP_PC
#    5230 mc4 SP_PC
#    5232 mc2 SP_PC
#    5249 mc5 SP_PC
#    5299 mc3 SP_PC
#    5345 mc3 SP_PC
#    5351 mc3 SP_PC
#    5369 mc3 SP_PC
#    5370 mc1 SP_PC
#    5442 mc3 SP_PC
#    5501 mc0 SP_PC
#    5525 mc3 SP_PC
#    5527 mc3 SP_PC
#    5613 mc3 SP_PC
#    5699 mc4 SP_PC
#    5730 mc3 SP_PC
#    5748 mc3 SP_PC
#    5816 mc0 SP_PC
#    5929 mc0 SP_PC
#    5991 mc3 SP_PC
#    6074 mc3 SP_PC
#    6133 mc0 SP_PC
#    6152 mc0 SP_PC
#    6183 mc1 SP_PC
#    6203 mc0 SP_PC
#    6210 mc0 SP_PC
#    6245 mc0 SP_PC
#    6419 mc1 SP_PC
#    6499 mc2 SP_PC
#    6529 mc6 SP_PC
#    6574 mc2 SP_PC
#    6585 mc2 SP_PC
#    6625 mc3 SP_PC
#    6713 mc4 SP_PC
#    6789 mc6 SP_PC
#    6815 mc3 SP_PC
#    6830 mc0 SP_PC
#    6925 mc3 SP_PC
#    7062 mc2 SP_PC
#    7080 mc3 SP_PC
#    7143 mc2 SP_PC
#    7207 mc0 SP_PC
#    7385 mc2 SP_PC
#    7435 mc1 SP_PC
#    7446 mc6 SP_PC
#    7487 mc0 SP_PC
#    7657 mc2 SP_PC
#    7792 mc2 SP_PC
#    7799 mc1 SP_PC
#    7847 mc0 SP_PC
#    7877 mc0 SP_PC
#    7946 mc6 SP_PC
#    7959 mc0 SP_PC
#    7994 mc0 SP_PC
#    7999 mc3 SP_PC
#    8062 mc3 SP_PC
#    8067 mc2 SP_PC
#    8074 mc1 SP_PC
#    8289 mc2 SP_PC
#    8296 mc3 SP_PC
#    8311 mc3 SP_PC
#    8431 mc0 SP_PC
#    8567 mc3 SP_PC
#    8571 mc1 SP_PC
#    8640 mc0 SP_PC
#    8646 mc3 SP_PC
#    8677 mc3 SP_PC
#    8690 mc3 SP_PC
#    8728 mc2 SP_PC
#    8771 mc3 SP_PC
#    8777 mc4 SP_PC
#    8794 mc4 SP_PC
#    8838 mc1 SP_PC
#    8849 mc2 SP_PC
#    8859 mc3 SP_PC
#    8874 mc0 SP_PC
#    8877 mc2 SP_PC
#    8905 mc3 SP_PC
#    9171 mc0 SP_PC
#    9249 mc3 SP_PC
#    9317 mc1 SP_PC
#    9440 mc2 SP_PC
#    9445 mc5 SP_PC
#    9453 mc3 SP_PC
#    9502 mc2 SP_PC
#    9574 mc2 SP_PC
#    9844 mc3 SP_PC
#    9855 mc3 SP_PC
#    9859 mc3 SP_PC
#    9888 mc1 SP_PC
#    9934 mc3 SP_PC
#    10056 mc2 SP_PC
#    10103 mc5 SP_PC
#    10143 mc5 SP_PC
#    10170 mc2 SP_PC
#    10244 mc3 SP_PC
#    10249 mc3 SP_PC
#    10302 mc3 SP_PC
#    10381 mc3 SP_PC
#    10421 mc1 SP_PC
#    10429 mc1 SP_PC
#    10499 mc0 SP_PC
#    10536 mc2 SP_PC
#    10545 mc3 SP_PC
#    10649 mc6 SP_PC
#    10742 mc2 SP_PC
#    10749 mc1 SP_PC
#    10781 mc0 SP_PC
#    10810 mc6 SP_PC
#    10851 mc4 SP_PC
#    10897 mc6 SP_PC
#    10906 mc2 SP_PC
#    10935 mc5 SP_PC
#    10994 mc2 SP_PC
#    11111 mc0 SP_PC
#    11128 mc0 SP_PC
#    11162 mc0 SP_PC
#    11166 mc3 SP_PC
#    11240 mc3 SP_PC
#    11253 mc3 SP_PC
#    11273 mc3 SP_PC
#    11289 mc0 SP_PC
#    11339 mc0 SP_PC
#    11404 mc2 SP_PC
#    11418 mc3 SP_PC
#    11445 mc0 SP_PC
#    11576 mc0 SP_PC
#    11579 mc3 SP_PC
#    11646 mc2 SP_PC
#    11681 mc3 SP_PC
#    11682 mc0 SP_PC
#    11751 mc3 SP_PC
#    11840 mc3 SP_PC
#    11909 mc3 SP_PC
#    12164 mc3 SP_PC
#    12246 mc4 SP_PC
#    12381 mc2 SP_PC
#    12387 mc0 SP_PC
#    12466 mc6 SP_PC
#    12476 mc3 SP_PC
#    12652 mc3 SP_PC
#    12678 mc6 SP_PC
#    12719 mc0 SP_PC
#    12771 mc3 SP_PC
#    12789 mc3 SP_PC
#    12942 mc2 SP_PC
#    13018 mc1 SP_PC
#    13024 mc0 SP_PC
#    13088 mc3 SP_PC
#    13107 mc2 SP_PC
#    13112 mc1 SP_PC
#    13138 mc1 SP_PC
#    13145 mc3 SP_PC
#    13163 mc1 SP_PC
#    13262 mc2 SP_PC
#    13395 mc3 SP_PC
#    13457 mc0 SP_PC
#    13541 mc3 SP_PC
#    13584 mc0 SP_PC
#    13608 mc0 SP_PC
#    13657 mc0 SP_PC
#    13692 mc3 SP_PC
#    13717 mc3 SP_PC
#    13754 mc2 SP_PC
#    13799 mc1 SP_PC
#    13841 mc0 SP_PC
#    13851 mc2 SP_PC
#    13938 mc0 SP_PC
#    14050 mc0 SP_PC
#    14100 mc5 SP_PC
#    14253 mc1 SP_PC
#    14277 mc3 SP_PC
#    14329 mc0 SP_PC
#    14416 mc2 SP_PC
#    14443 mc3 SP_PC
#    14460 mc2 SP_PC
#    14638 mc3 SP_PC
#    14656 mc2 SP_PC
#    14679 mc0 SP_PC
#    14680 mc5 SP_PC
#    14842 mc3 SP_PC
#    14844 mc3 SP_PC
#    14885 mc0 SP_PC
#    14907 mc6 SP_PC
#    14941 mc3 SP_PC
#    14983 mc3 SP_PC
#    14992 mc3 SP_PC
#    15018 mc1 SP_PC
#    15019 mc3 SP_PC
#    15031 mc1 SP_PC
#    15044 mc0 SP_PC
#    15073 mc3 SP_PC
#    15074 mc3 SP_PC
#    15089 mc2 SP_PC
#    15090 mc1 SP_PC
#    15101 mc0 SP_PC
#    15180 mc3 SP_PC
#    15357 mc0 SP_PC
#    15379 mc0 SP_PC
#    15395 mc0 SP_PC
#    15542 mc5 SP_PC
#    15641 mc3 SP_PC
#    15707 mc0 SP_PC
#    15789 mc3 SP_PC
#    15973 mc0 SP_PC
#    16054 mc2 SP_PC
#    16160 mc2 SP_PC
#    16163 mc0 SP_PC
#    16238 mc2 SP_PC
#    16291 mc6 SP_PC
#    16317 mc3 SP_PC
#    16356 mc3 SP_PC
#    16430 mc1 SP_PC
#    16434 mc0 SP_PC
#    16463 mc3 SP_PC
#    16467 mc6 SP_PC
#    16492 mc0 SP_PC
#    16563 mc3 SP_PC
#    16640 mc2 SP_PC
#    16743 mc3 SP_PC
#    16755 mc3 SP_PC
#    16929 mc3 SP_PVBC
#    16945 mc1 SP_PVBC
#    16989 mc3 SP_PVBC
#    17072 mc0 SP_PVBC
#    17113 mc3 SP_PVBC
#    17157 mc0 SP_PVBC
#    17208 mc0 SP_CCKBC
#    17209 mc0 SP_CCKBC
#    17217 mc0 SP_CCKBC
#    17225 mc0 SP_CCKBC
#    17252 mc0 SP_CCKBC
#    17268 mc0 SP_CCKBC
#    17273 mc0 SP_CCKBC
#    17277 mc0 SP_CCKBC
#    17285 mc3 SP_CCKBC
#    17289 mc0 SP_CCKBC
#    17297 mc0 SP_CCKBC
#    17312 mc0 SP_CCKBC
#    17325 mc0 SP_CCKBC
#    17378 mc3 SP_CCKBC
#    17405 mc0 SP_BS
#    17408 mc0 SP_BS
#    17445 mc3 SP_BS
#    17453 mc3 SP_BS
#    17464 mc0 SP_BS
#    17603 mc0 SP_Ivy
#    17665 mc0 SP_Ivy
#    17677 mc0 SP_Ivy
#    17714 mc0 SP_Ivy
#    17768 mc3 SP_Ivy
#    17780 mc0 SP_Ivy
#    17787 mc0 SP_Ivy
#    17857 mc0 SP_Ivy
#    18021 mc0 SP_Ivy
#    18042 mc3 SO_OLM
#    18044 mc0 SO_OLM
#    18105 mc0 SO_OLM
#    18114 mc3 SO_OLM
#    18166 mc3 SO_Tri
#    18180 mc3 SO_Tri
#    18182 mc0 SO_Tri
#    18193 mc3 SO_BP

# %%
# we sample the edges to reduce the memory usage
N = 10000
sampled_edge_ids = np.random.choice(conn.size, N, replace=False)

# %%
print(conn.size, cells.size)
# Out:
# 19698045 18198

# %%
import nrrd

# %%
atlas_directory = '/home/fernando/CA1__/data-bbp/20191017/atlas'
br_data, br_metadata = nrrd.read(Path(atlas_directory, "brain_regions.nrrd"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-148-aa5697b9d8ae> in <module>
#       1 atlas_directory = '/home/fernando/CA1__/data-bbp/20191017/atlas'
# ----> 2 br_data, br_metadata = nrrd.read(Path(atlas_directory, "brain_regions.nrrd"))
#
# TypeError: 'str' object is not callable

# %%
atlas_directory = '/home/fernando/CA1__/data-bbp/20191017/atlas'
br_data, br_metadata = nrrd.read(Path(atlas_directory, "brain_regions.nrrd"))

# hierarchy contains the region hierarchy: 01 -> [mc0->[mc0;SO, mc0;SP, ...], mc1-> [mc1;SO, mc1;SP, ...], ...]
hierarchy = json.load(open(Path(atlas_directory, "hierarchy.json")))

id_layer_map = {}
for column in hierarchy["children"]:
    for region in column["children"]:
        id_ = region["id"]
        layer = region["acronym"].split(";")[-1]
        id_layer_map[id_] = layer
id_layer_map[0] = 'out'

spacing = br_metadata["space directions"].diagonal()
offset = br_metadata["space origin"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-147-7d0be4dd9efa> in <module>
#       3
#       4 # hierarchy contains the region hierarchy: 01 -> [mc0->[mc0;SO, mc0;SP, ...], mc1-> [mc1;SO, mc1;SP, ...], ...]
# ----> 5 hierarchy = json.load('/home/fernando/CA1__/data-bbp/20191017/atlashierarchy.json')
#       6
#       7 id_layer_map = {}
#
# ~/anaconda3/envs/netpynedev/lib/python3.7/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# AttributeError: 'str' object has no attribute 'read'

# %%
# we get the position of all the synapses from the projections and add it to a pandas dataframe
synapses = conn.positions(sampled_edge_ids, 'afferent', "center")

indices = np.array((synapses[["x", "y", "z"]].to_numpy() - offset) / spacing, dtype=int)
labels = br_data[tuple(indices.T)]
def _apply_mapping(x):
    return id_layer_map[x]

apply_mapping = np.vectorize(_apply_mapping)
layers = apply_mapping(labels)
synapses['layer'] = layers
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-140-84685b3a3f6b> in <module>
#       2 synapses = conn.positions(sampled_edge_ids, 'afferent', "center")
#       3
# ----> 4 indices = np.array((synapses[["x", "y", "z"]].to_numpy() - offset) / spacing, dtype=int)
#       5 labels = br_data[tuple(indices.T)]
#       6 def _apply_mapping(x):
#
# NameError: name 'offset' is not defined
